# %%
import pandas as pd
import re

# %%
# pd = pd.read_csv('to_download.txt', sep=' 	', header=None)
file_path = 'data/to_download.txt'

with open(file_path, 'r') as file:
    lines = file.readlines()

# pattern = re.compile(r'(\d{4} \w+ \(\w+-\w+\)-\w+\.csv)\s+(\w+ \d{1,2}[a-z]{2} \d{4}, \d{2}:\d{2}:\d{2} [ap]m)\s+([\d.]+ \wB)\s+(CSV file)')
pattern = re.compile(r'(.*?\.csv)\s+(\w+ \d{1,2}[a-z]{2} \d{4}, \d{2}:\d{2}:\d{2} [ap]m)\s+([\d.]+ \wB)\s+(CSV file)')

data = []
for line in lines:
    match = pattern.match(line)
    if match:
        data.append(match.groups())

# Create a DataFrame
df = pd.DataFrame(data, columns=['File Name', 'Date', 'Size', 'Type'])

df['File Name No Space'] = df['File Name'].str.replace(' ', '%20')

# %%
df.head()
# Out:
#                                       File Name                        Date  \
# 0      01aJourneyDataExtract10Jan16-23Jan16.csv  Aug 24th 2016, 03:46:34 pm
# 1  01b Journey Data Extract 24Jan16-06Feb16.csv  Aug 23rd 2016, 10:16:33 am
# 2      01bJourneyDataExtract24Jan16-06Feb16.csv  Aug 24th 2016, 03:46:42 pm
# 3     02aJourneyDataExtract07Fe16-20Feb2016.csv  Mar 11th 2016, 11:38:10 am
# 4    02bJourneyDataExtract21Feb16-05Mar2016.csv  Mar 11th 2016, 11:37:48 am
#
#        Size      Type                                 File Name No Space
# 0  34.45 MB  CSV file           01aJourneyDataExtract10Jan16-23Jan16.csv
# 1  35.49 MB  CSV file  01b%20Journey%20Data%20Extract%2024Jan16-06Feb...
# 2  35.49 MB  CSV file           01bJourneyDataExtract24Jan16-06Feb16.csv
# 3  33.29 MB  CSV file          02aJourneyDataExtract07Fe16-20Feb2016.csv
# 4  34.88 MB  CSV file         02bJourneyDataExtract21Feb16-05Mar2016.csv

# %%
df['File Name No Space'].tolist()
# Out:
# ['01aJourneyDataExtract10Jan16-23Jan16.csv',
#  '01b%20Journey%20Data%20Extract%2024Jan16-06Feb16.csv',
#  '01bJourneyDataExtract24Jan16-06Feb16.csv',
#  '02aJourneyDataExtract07Fe16-20Feb2016.csv',
#  '02bJourneyDataExtract21Feb16-05Mar2016.csv',
#  '03JourneyDataExtract06Mar2016-31Mar2016.csv',
#  '04JourneyDataExtract01Apr2016-30Apr2016.csv',
#  '05JourneyDataExtract01May2016-17May2016.csv',
#  '06JourneyDataExtract18May2016-24May2016.csv',
#  '07JourneyDataExtract25May2016-31May2016.csv',
#  '08JourneyDataExtract01Jun2016-07Jun2016.csv',
#  '09JourneyDataExtract08Jun2016-14Jun2016.csv',
#  '100JourneyDataExtract07Mar2018-13Mar2018.csv',
#  '101JourneyDataExtract14Mar2018-20Mar2018.csv',
#  '102JourneyDataExtract21Mar2018-27Mar2018.csv',
#  '103JourneyDataExtract28Mar2018-03Apr2018.csv',
#  '104JourneyDataExtract04Apr2018-10Apr2018.csv',
#  '105JourneyDataExtract11Apr2018-17Apr2018.csv',
#  '106JourneyDataExtract18Apr2018-24Apr2018.csv',
# ...
